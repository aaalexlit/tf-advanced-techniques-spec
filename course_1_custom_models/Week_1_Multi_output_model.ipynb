# %% [markdown]
# <a href="https://colab.research.google.com/github/aaalexlit/tf-advanced-techniques-spec/blob/main/course_1_custom_models%20/Week_1_Multi_output_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab to build models with more than one output
# ## Dataset
# https://archive.ics.uci.edu/ml/datasets/energy+efficiency
#
# ### Data Set Information:
#
# We perform energy analysis using 12 different building shapes simulated in Ecotect. The buildings differ with respect to the glazing area, the glazing area distribution, and the orientation, amongst other parameters. We simulate various settings as functions of the afore-mentioned characteristics to obtain 768 building shapes. The dataset comprises 768 samples and 8 features, aiming to predict two real valued responses. It can also be used as a multi-class classification problem if the response is rounded to the nearest integer.
#
# ### Attribute Information:
#
# The dataset contains eight attributes (or features, denoted by X1...X8) and two responses (or outcomes, denoted by y1 and y2). The aim is to use the eight features to predict each of the two responses.
#
# Specifically:
# X1 Relative Compactness
# X2 Surface Area
# X3 Wall Area
# X4 Roof Area
# X5 Overall Height
# X6 Orientation
# X7 Glazing Area
# X8 Glazing Area Distribution
#
# y1 Heating Load
# y2 Cooling Load

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# For data conversion and visualization

# %%
# convert output labels to numpy arrays
def format_output(data):
  y1 = data.pop('Y1')
  y1 = np.array(y1)
  y2 = data.pop('Y2')
  y2 = np.array(y2)
  return y1, y2


#standardize the input 
def norm(x):
  return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
  plt.scatter(y_true, y_pred)
  plt.title(title)
  plt.xlabel('True values')
  plt.ylabel('Predictions')
  plt.axis('equal')
  plt.axis('square')
  plt.xlim(plt.xlim())
  plt.ylim(plt.ylim())
  # plot diagonal line
  plt.plot([-100, 100], [-100, 100])
  plt.show()


def plot_metrics(metric_name, title, ylim=5):
  plt.title(title)
  plt.ylim(0, ylim)
  plt.plot(history.history[metric_name], color='blue', label=metric_name)
  plt.plot(history.history[f'val_{metric_name}'], color='green', label=f'val_{metric_name}')
  plt.show()

# %% [markdown]
# ## Prepare the data
# Download the dataset and format it for training

# %%
URI = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx'

# Use pandas read_excel
df = pd.read_excel(URI)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Remove the dependent variables from stats
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()

# Extract labels from the dataset and convert them to numpy arrays
train_Y = format_output(train)
test_Y = format_output(test)

# Standadize the features
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the model
# Notice that we can specify a list of outputs (i.e. [y1_output, y2_output]) when we instantiate the Model() class.

# %%
input_layer = Input(shape=(len(train.columns),))
first_dense = Dense(units=128, activation='relu', name='first_dense')(input_layer)
second_dense = Dense(units=128, activation='relu', name='second_dense')(first_dense)

y1_output = Dense(units=1, name='y1_output')(second_dense)
third_dense = Dense(units=128, activation='relu', name='third_dense')(second_dense)

y2_output = Dense(units=1, name='y2_output')(third_dense)

model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 8)]          0           []
#
#  first_dense (Dense)            (None, 128)          1152        ['input_1[0][0]']
#
#  second_dense (Dense)           (None, 128)          16512       ['first_dense[0][0]']
#
#  third_dense (Dense)            (None, 128)          16512       ['second_dense[0][0]']
#
#  y1_output (Dense)              (None, 1)            129         ['second_dense[0][0]']
#
#  y2_output (Dense)              (None, 1)            129         ['third_dense[0][0]']
#
# ==================================================================================================
# Total params: 34,434
# Trainable params: 34,434
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Plot the model

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# ## Configure parameters
# Here it's redundant, but we specify the optimizer as well as the loss and metrics for each output to show that it can be done

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(), 
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the model

# %%
train
# Out:
#        X1     X2     X3      X4   X5  X6    X7  X8
# 267  0.74  686.0  245.0  220.50  3.5   5  0.10   5
# 399  0.82  612.5  318.5  147.00  7.0   5  0.25   3
# 335  0.62  808.5  367.5  220.50  3.5   5  0.25   1
# 409  0.74  686.0  245.0  220.50  3.5   3  0.25   3
# 445  0.82  612.5  318.5  147.00  7.0   3  0.25   4
# ..    ...    ...    ...     ...  ...  ..   ...  ..
# 507  0.74  686.0  245.0  220.50  3.5   5  0.25   5
# 19   0.79  637.0  343.0  147.00  7.0   5  0.00   0
# 339  0.98  514.5  294.0  110.25  7.0   5  0.25   2
# 264  0.74  686.0  245.0  220.50  3.5   2  0.10   5
# 64   0.79  637.0  343.0  147.00  7.0   2  0.10   1
#
# [614 rows x 8 columns]

# %%
history = model.fit(norm_train_X, 
                    train_Y,
                    epochs=500,
                    batch_size=10, 
                    validation_data=(norm_test_X, test_Y))
# Out:
# Epoch 1/500
# 62/62 [==============================] - 2s 11ms/step - loss: 242.1826 - y1_output_loss: 119.5124 - y2_output_loss: 122.6701 - y1_output_root_mean_squared_error: 10.9322 - y2_output_root_mean_squared_error: 11.0757 - val_loss: 248.6841 - val_y1_output_loss: 70.7498 - val_y2_output_loss: 177.9343 - val_y1_output_root_mean_squared_error: 8.4113 - val_y2_output_root_mean_squared_error: 13.3392
# Epoch 2/500
# 62/62 [==============================] - 0s 4ms/step - loss: 37.5608 - y1_output_loss: 13.4972 - y2_output_loss: 24.0636 - y1_output_root_mean_squared_error: 3.6739 - y2_output_root_mean_squared_error: 4.9055 - val_loss: 26.9915 - val_y1_output_loss: 10.3992 - val_y2_output_loss: 16.5923 - val_y1_output_root_mean_squared_error: 3.2248 - val_y2_output_root_mean_squared_error: 4.0734
# Epoch 3/500
# 62/62 [==============================] - 0s 3ms/step - loss: 29.2480 - y1_output_loss: 11.0965 - y2_output_loss: 18.1514 - y1_output_root_mean_squared_error: 3.3311 - y2_output_root_mean_squared_error: 4.2604 - val_loss: 20.1035 - val_y1_output_loss: 9.3642 - val_y2_output_loss: 10.7393 - val_y1_output_root_mean_squared_error: 3.0601 - val_y2_output_root_mean_squared_error: 3.2771
# Epoch 4/500
# 62/62 [==============================] - 0s 4ms/step - loss: 23.7543 - y1_output_loss: 9.5974 - y2_output_loss: 14.1570 - y1_output_root_mean_squared_error: 3.0980 - y2_output_root_mean_squared_error: 3.7626 - val_loss: 25.4755 - val_y1_output_loss: 9.9072 - val_y2_output_loss: 15.5683 - val_y1_output_root_mean_squared_error: 3.1476 - val_y2_output_root_mean_squared_error: 3.9457
# Epoch 5/500
# 62/62 [==============================] - 0s 6ms/step - loss: 21.0819 - y1_output_loss: 8.8356 - y2_output_loss: 12.2463 - y1_output_root_mean_squared_error: 2.9725 - y2_output_root_mean_squared_error: 3.4995 - val_loss: 29.0706 - val_y1_output_loss: 10.7212 - val_y2_output_loss: 18.3493 - val_y1_output_root_mean_squared_error: 3.2743 - val_y2_output_root_mean_squared_error: 4.2836
# Epoch 6/500
# 62/62 [==============================] - 0s 5ms/step - loss: 24.9326 - y1_output_loss: 9.2226 - y2_output_loss: 15.7099 - y1_output_root_mean_squared_error: 3.0369 - y2_output_root_mean_squared_error: 3.9636 - val_loss: 18.3096 - val_y1_output_loss: 8.2113 - val_y2_output_loss: 10.0982 - val_y1_output_root_mean_squared_error: 2.8655 - val_y2_output_root_mean_squared_error: 3.1778
# Epoch 7/500
# 62/62 [==============================] - 0s 4ms/step - loss: 23.6094 - y1_output_loss: 8.9114 - y2_output_loss: 14.6981 - y1_output_root_mean_squared_error: 2.9852 - y2_output_root_mean_squared_error: 3.8338 - val_loss: 31.5238 - val_y1_output_loss: 11.5966 - val_y2_output_loss: 19.9272 - val_y1_output_root_mean_squared_error: 3.4054 - val_y2_output_root_mean_squared_error: 4.4640
# Epoch 8/500
# 62/62 [==============================] - 0s 6ms/step - loss: 29.1984 - y1_output_loss: 9.8893 - y2_output_loss: 19.3092 - y1_output_root_mean_squared_error: 3.1447 - y2_output_root_mean_squared_error: 4.3942 - val_loss: 17.8374 - val_y1_output_loss: 8.0586 - val_y2_output_loss: 9.7788 - val_y1_output_root_mean_squared_error: 2.8388 - val_y2_output_root_mean_squared_error: 3.1271
# Epoch 9/500
# 62/62 [==============================] - 0s 4ms/step - loss: 24.9844 - y1_output_loss: 9.1580 - y2_output_loss: 15.8264 - y1_output_root_mean_squared_error: 3.0262 - y2_output_root_mean_squared_error: 3.9782 - val_loss: 19.1209 - val_y1_output_loss: 8.1922 - val_y2_output_loss: 10.9286 - val_y1_output_root_mean_squared_error: 2.8622 - val_y2_output_root_mean_squared_error: 3.3058
# Epoch 10/500
# 62/62 [==============================] - 0s 4ms/step - loss: 19.8616 - y1_output_loss: 8.1664 - y2_output_loss: 11.6951 - y1_output_root_mean_squared_error: 2.8577 - y2_output_root_mean_squared_error: 3.4198 - val_loss: 38.0384 - val_y1_output_loss: 11.9761 - val_y2_output_loss: 26.0623 - val_y1_output_root_mean_squared_error: 3.4606 - val_y2_output_root_mean_squared_error: 5.1051
# Epoch 11/500
# 62/62 [==============================] - 0s 5ms/step - loss: 20.2378 - y1_output_loss: 8.1980 - y2_output_loss: 12.0398 - y1_output_root_mean_squared_error: 2.8632 - y2_output_root_mean_squared_error: 3.4698 - val_loss: 34.6966 - val_y1_output_loss: 12.9714 - val_y2_output_loss: 21.7251 - val_y1_output_root_mean_squared_error: 3.6016 - val_y2_output_root_mean_squared_error: 4.6610
# Epoch 12/500
# 62/62 [==============================] - 0s 4ms/step - loss: 21.7937 - y1_output_loss: 8.5367 - y2_output_loss: 13.2570 - y1_output_root_mean_squared_error: 2.9218 - y2_output_root_mean_squared_error: 3.6410 - val_loss: 82.6313 - val_y1_output_loss: 21.0901 - val_y2_output_loss: 61.5412 - val_y1_output_root_mean_squared_error: 4.5924 - val_y2_output_root_mean_squared_error: 7.8448
# Epoch 13/500
# 62/62 [==============================] - 0s 6ms/step - loss: 21.8389 - y1_output_loss: 8.1938 - y2_output_loss: 13.6451 - y1_output_root_mean_squared_error: 2.8625 - y2_output_root_mean_squared_error: 3.6939 - val_loss: 21.3399 - val_y1_output_loss: 9.5566 - val_y2_output_loss: 11.7832 - val_y1_output_root_mean_squared_error: 3.0914 - val_y2_output_root_mean_squared_error: 3.4327
# Epoch 14/500
# 62/62 [==============================] - 0s 4ms/step - loss: 19.5264 - y1_output_loss: 7.6612 - y2_output_loss: 11.8653 - y1_output_root_mean_squared_error: 2.7679 - y2_output_root_mean_squared_error: 3.4446 - val_loss: 46.7391 - val_y1_output_loss: 18.7065 - val_y2_output_loss: 28.0326 - val_y1_output_root_mean_squared_error: 4.3251 - val_y2_output_root_mean_squared_error: 5.2946
# Epoch 15/500
# 62/62 [==============================] - 0s 4ms/step - loss: 22.8530 - y1_output_loss: 8.7973 - y2_output_loss: 14.0557 - y1_output_root_mean_squared_error: 2.9660 - y2_output_root_mean_squared_error: 3.7491 - val_loss: 26.8497 - val_y1_output_loss: 9.1564 - val_y2_output_loss: 17.6933 - val_y1_output_root_mean_squared_error: 3.0260 - val_y2_output_root_mean_squared_error: 4.2063
# Epoch 16/500
# 62/62 [==============================] - 0s 3ms/step - loss: 22.3100 - y1_output_loss: 8.1220 - y2_output_loss: 14.1880 - y1_output_root_mean_squared_error: 2.8499 - y2_output_root_mean_squared_error: 3.7667 - val_loss: 17.9165 - val_y1_output_loss: 8.6752 - val_y2_output_loss: 9.2413 - val_y1_output_root_mean_squared_error: 2.9454 - val_y2_output_root_mean_squared_error: 3.0400
# Epoch 17/500
# 62/62 [==============================] - 0s 5ms/step - loss: 21.7972 - y1_output_loss: 8.2096 - y2_output_loss: 13.5877 - y1_output_root_mean_squared_error: 2.8652 - y2_output_root_mean_squared_error: 3.6861 - val_loss: 17.3829 - val_y1_output_loss: 7.3792 - val_y2_output_loss: 10.0037 - val_y1_output_root_mean_squared_error: 2.7165 - val_y2_output_root_mean_squared_error: 3.1629
# Epoch 18/500
# 62/62 [==============================] - 0s 8ms/step - loss: 18.7981 - y1_output_loss: 7.3487 - y2_output_loss: 11.4494 - y1_output_root_mean_squared_error: 2.7109 - y2_output_root_mean_squared_error: 3.3837 - val_loss: 17.0768 - val_y1_output_loss: 7.3860 - val_y2_output_loss: 9.6908 - val_y1_output_root_mean_squared_error: 2.7177 - val_y2_output_root_mean_squared_error: 3.1130
# Epoch 19/500
# 62/62 [==============================] - 0s 5ms/step - loss: 16.1723 - y1_output_loss: 6.5897 - y2_output_loss: 9.5826 - y1_output_root_mean_squared_error: 2.5670 - y2_output_root_mean_squared_error: 3.0956 - val_loss: 17.6656 - val_y1_output_loss: 7.4398 - val_y2_output_loss: 10.2258 - val_y1_output_root_mean_squared_error: 2.7276 - val_y2_output_root_mean_squared_error: 3.1978
# Epoch 20/500
# 62/62 [==============================] - 0s 6ms/step - loss: 18.6479 - y1_output_loss: 7.1977 - y2_output_loss: 11.4502 - y1_output_root_mean_squared_error: 2.6828 - y2_output_root_mean_squared_error: 3.3838 - val_loss: 41.8344 - val_y1_output_loss: 13.0430 - val_y2_output_loss: 28.7914 - val_y1_output_root_mean_squared_error: 3.6115 - val_y2_output_root_mean_squared_error: 5.3658
# Epoch 21/500
# 62/62 [==============================] - 0s 5ms/step - loss: 38.4375 - y1_output_loss: 10.8949 - y2_output_loss: 27.5426 - y1_output_root_mean_squared_error: 3.3007 - y2_output_root_mean_squared_error: 5.2481 - val_loss: 19.5136 - val_y1_output_loss: 8.6461 - val_y2_output_loss: 10.8675 - val_y1_output_root_mean_squared_error: 2.9404 - val_y2_output_root_mean_squared_error: 3.2966
# Epoch 22/500
# 62/62 [==============================] - 1s 10ms/step - loss: 18.2931 - y1_output_loss: 6.5611 - y2_output_loss: 11.7320 - y1_output_root_mean_squared_error: 2.5615 - y2_output_root_mean_squared_error: 3.4252 - val_loss: 16.3091 - val_y1_output_loss: 7.3567 - val_y2_output_loss: 8.9524 - val_y1_output_root_mean_squared_error: 2.7123 - val_y2_output_root_mean_squared_error: 2.9921
# Epoch 23/500
# 62/62 [==============================] - 1s 10ms/step - loss: 19.5026 - y1_output_loss: 7.1355 - y2_output_loss: 12.3671 - y1_output_root_mean_squared_error: 2.6712 - y2_output_root_mean_squared_error: 3.5167 - val_loss: 46.4326 - val_y1_output_loss: 11.6949 - val_y2_output_loss: 34.7377 - val_y1_output_root_mean_squared_error: 3.4198 - val_y2_output_root_mean_squared_error: 5.8939
# Epoch 24/500
# 62/62 [==============================] - 0s 6ms/step - loss: 18.2044 - y1_output_loss: 7.0272 - y2_output_loss: 11.1771 - y1_output_root_mean_squared_error: 2.6509 - y2_output_root_mean_squared_error: 3.3432 - val_loss: 38.4112 - val_y1_output_loss: 13.7618 - val_y2_output_loss: 24.6494 - val_y1_output_root_mean_squared_error: 3.7097 - val_y2_output_root_mean_squared_error: 4.9648
# Epoch 25/500
# 62/62 [==============================] - 1s 8ms/step - loss: 19.8609 - y1_output_loss: 6.9015 - y2_output_loss: 12.9593 - y1_output_root_mean_squared_error: 2.6271 - y2_output_root_mean_squared_error: 3.5999 - val_loss: 22.6720 - val_y1_output_loss: 8.6339 - val_y2_output_loss: 14.0380 - val_y1_output_root_mean_squared_error: 2.9384 - val_y2_output_root_mean_squared_error: 3.7467
# Epoch 26/500
# 62/62 [==============================] - 1s 11ms/step - loss: 16.5535 - y1_output_loss: 6.2154 - y2_output_loss: 10.3381 - y1_output_root_mean_squared_error: 2.4931 - y2_output_root_mean_squared_error: 3.2153 - val_loss: 17.3198 - val_y1_output_loss: 6.4265 - val_y2_output_loss: 10.8934 - val_y1_output_root_mean_squared_error: 2.5351 - val_y2_output_root_mean_squared_error: 3.3005
# Epoch 27/500
# 62/62 [==============================] - 1s 9ms/step - loss: 15.9987 - y1_output_loss: 5.8530 - y2_output_loss: 10.1458 - y1_output_root_mean_squared_error: 2.4193 - y2_output_root_mean_squared_error: 3.1852 - val_loss: 18.8135 - val_y1_output_loss: 7.6502 - val_y2_output_loss: 11.1633 - val_y1_output_root_mean_squared_error: 2.7659 - val_y2_output_root_mean_squared_error: 3.3411
# Epoch 28/500
# 62/62 [==============================] - 1s 13ms/step - loss: 15.3899 - y1_output_loss: 6.1075 - y2_output_loss: 9.2825 - y1_output_root_mean_squared_error: 2.4713 - y2_output_root_mean_squared_error: 3.0467 - val_loss: 16.5804 - val_y1_output_loss: 6.3926 - val_y2_output_loss: 10.1878 - val_y1_output_root_mean_squared_error: 2.5284 - val_y2_output_root_mean_squared_error: 3.1918
# Epoch 29/500
# 62/62 [==============================] - 0s 3ms/step - loss: 15.8874 - y1_output_loss: 5.9067 - y2_output_loss: 9.9807 - y1_output_root_mean_squared_error: 2.4304 - y2_output_root_mean_squared_error: 3.1592 - val_loss: 11.4866 - val_y1_output_loss: 5.1983 - val_y2_output_loss: 6.2884 - val_y1_output_root_mean_squared_error: 2.2800 - val_y2_output_root_mean_squared_error: 2.5077
# Epoch 30/500
# 62/62 [==============================] - 0s 4ms/step - loss: 13.5080 - y1_output_loss: 5.3223 - y2_output_loss: 8.1857 - y1_output_root_mean_squared_error: 2.3070 - y2_output_root_mean_squared_error: 2.8611 - val_loss: 17.7205 - val_y1_output_loss: 5.8288 - val_y2_output_loss: 11.8917 - val_y1_output_root_mean_squared_error: 2.4143 - val_y2_output_root_mean_squared_error: 3.4484
# Epoch 31/500
# 62/62 [==============================] - 0s 3ms/step - loss: 13.2838 - y1_output_loss: 4.9780 - y2_output_loss: 8.3058 - y1_output_root_mean_squared_error: 2.2311 - y2_output_root_mean_squared_error: 2.8820 - val_loss: 25.6721 - val_y1_output_loss: 9.0839 - val_y2_output_loss: 16.5881 - val_y1_output_root_mean_squared_error: 3.0140 - val_y2_output_root_mean_squared_error: 4.0729
# Epoch 32/500
# 62/62 [==============================] - 0s 3ms/step - loss: 12.0229 - y1_output_loss: 4.8062 - y2_output_loss: 7.2167 - y1_output_root_mean_squared_error: 2.1923 - y2_output_root_mean_squared_error: 2.6864 - val_loss: 12.6239 - val_y1_output_loss: 5.7657 - val_y2_output_loss: 6.8582 - val_y1_output_root_mean_squared_error: 2.4012 - val_y2_output_root_mean_squared_error: 2.6188
# Epoch 33/500
# 62/62 [==============================] - 0s 3ms/step - loss: 16.2630 - y1_output_loss: 5.7082 - y2_output_loss: 10.5548 - y1_output_root_mean_squared_error: 2.3892 - y2_output_root_mean_squared_error: 3.2488 - val_loss: 25.2037 - val_y1_output_loss: 11.8239 - val_y2_output_loss: 13.3798 - val_y1_output_root_mean_squared_error: 3.4386 - val_y2_output_root_mean_squared_error: 3.6578
# Epoch 34/500
# 62/62 [==============================] - 0s 3ms/step - loss: 11.0311 - y1_output_loss: 4.4089 - y2_output_loss: 6.6222 - y1_output_root_mean_squared_error: 2.0997 - y2_output_root_mean_squared_error: 2.5734 - val_loss: 9.5020 - val_y1_output_loss: 4.3079 - val_y2_output_loss: 5.1941 - val_y1_output_root_mean_squared_error: 2.0755 - val_y2_output_root_mean_squared_error: 2.2791
# Epoch 35/500
# 62/62 [==============================] - 0s 3ms/step - loss: 12.4040 - y1_output_loss: 4.4624 - y2_output_loss: 7.9416 - y1_output_root_mean_squared_error: 2.1124 - y2_output_root_mean_squared_error: 2.8181 - val_loss: 35.2272 - val_y1_output_loss: 8.1907 - val_y2_output_loss: 27.0365 - val_y1_output_root_mean_squared_error: 2.8619 - val_y2_output_root_mean_squared_error: 5.1997
# Epoch 36/500
# 62/62 [==============================] - 0s 4ms/step - loss: 13.0792 - y1_output_loss: 4.4368 - y2_output_loss: 8.6424 - y1_output_root_mean_squared_error: 2.1064 - y2_output_root_mean_squared_error: 2.9398 - val_loss: 18.8164 - val_y1_output_loss: 9.8395 - val_y2_output_loss: 8.9769 - val_y1_output_root_mean_squared_error: 3.1368 - val_y2_output_root_mean_squared_error: 2.9961
# Epoch 37/500
# 62/62 [==============================] - 0s 3ms/step - loss: 9.6200 - y1_output_loss: 3.4719 - y2_output_loss: 6.1481 - y1_output_root_mean_squared_error: 1.8633 - y2_output_root_mean_squared_error: 2.4795 - val_loss: 9.0159 - val_y1_output_loss: 3.8039 - val_y2_output_loss: 5.2120 - val_y1_output_root_mean_squared_error: 1.9504 - val_y2_output_root_mean_squared_error: 2.2830
# Epoch 38/500
# 62/62 [==============================] - 0s 3ms/step - loss: 9.0281 - y1_output_loss: 3.3657 - y2_output_loss: 5.6624 - y1_output_root_mean_squared_error: 1.8346 - y2_output_root_mean_squared_error: 2.3796 - val_loss: 8.9825 - val_y1_output_loss: 3.5598 - val_y2_output_loss: 5.4227 - val_y1_output_root_mean_squared_error: 1.8867 - val_y2_output_root_mean_squared_error: 2.3287
# Epoch 39/500
# 62/62 [==============================] - 0s 3ms/step - loss: 9.2674 - y1_output_loss: 3.4871 - y2_output_loss: 5.7804 - y1_output_root_mean_squared_error: 1.8674 - y2_output_root_mean_squared_error: 2.4042 - val_loss: 10.4922 - val_y1_output_loss: 3.4107 - val_y2_output_loss: 7.0816 - val_y1_output_root_mean_squared_error: 1.8468 - val_y2_output_root_mean_squared_error: 2.6611
# Epoch 40/500
# 62/62 [==============================] - 0s 4ms/step - loss: 9.3408 - y1_output_loss: 3.1921 - y2_output_loss: 6.1487 - y1_output_root_mean_squared_error: 1.7866 - y2_output_root_mean_squared_error: 2.4796 - val_loss: 10.0579 - val_y1_output_loss: 4.3408 - val_y2_output_loss: 5.7171 - val_y1_output_root_mean_squared_error: 2.0835 - val_y2_output_root_mean_squared_error: 2.3910
# Epoch 41/500
# 62/62 [==============================] - 0s 4ms/step - loss: 7.9493 - y1_output_loss: 2.8595 - y2_output_loss: 5.0898 - y1_output_root_mean_squared_error: 1.6910 - y2_output_root_mean_squared_error: 2.2561 - val_loss: 7.4244 - val_y1_output_loss: 2.9972 - val_y2_output_loss: 4.4272 - val_y1_output_root_mean_squared_error: 1.7312 - val_y2_output_root_mean_squared_error: 2.1041
# Epoch 42/500
# 62/62 [==============================] - 0s 3ms/step - loss: 8.0010 - y1_output_loss: 2.7227 - y2_output_loss: 5.2783 - y1_output_root_mean_squared_error: 1.6501 - y2_output_root_mean_squared_error: 2.2974 - val_loss: 10.9145 - val_y1_output_loss: 4.1755 - val_y2_output_loss: 6.7390 - val_y1_output_root_mean_squared_error: 2.0434 - val_y2_output_root_mean_squared_error: 2.5960
# Epoch 43/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.7996 - y1_output_loss: 2.1617 - y2_output_loss: 4.6379 - y1_output_root_mean_squared_error: 1.4703 - y2_output_root_mean_squared_error: 2.1536 - val_loss: 6.3741 - val_y1_output_loss: 2.5306 - val_y2_output_loss: 3.8435 - val_y1_output_root_mean_squared_error: 1.5908 - val_y2_output_root_mean_squared_error: 1.9605
# Epoch 44/500
# 62/62 [==============================] - 0s 4ms/step - loss: 11.2313 - y1_output_loss: 3.6939 - y2_output_loss: 7.5374 - y1_output_root_mean_squared_error: 1.9220 - y2_output_root_mean_squared_error: 2.7454 - val_loss: 12.8650 - val_y1_output_loss: 4.8336 - val_y2_output_loss: 8.0314 - val_y1_output_root_mean_squared_error: 2.1985 - val_y2_output_root_mean_squared_error: 2.8340
# Epoch 45/500
# 62/62 [==============================] - 0s 4ms/step - loss: 7.0665 - y1_output_loss: 2.3188 - y2_output_loss: 4.7477 - y1_output_root_mean_squared_error: 1.5228 - y2_output_root_mean_squared_error: 2.1789 - val_loss: 6.4731 - val_y1_output_loss: 2.4953 - val_y2_output_loss: 3.9778 - val_y1_output_root_mean_squared_error: 1.5796 - val_y2_output_root_mean_squared_error: 1.9944
# Epoch 46/500
# 62/62 [==============================] - 0s 6ms/step - loss: 8.9363 - y1_output_loss: 2.7712 - y2_output_loss: 6.1652 - y1_output_root_mean_squared_error: 1.6647 - y2_output_root_mean_squared_error: 2.4830 - val_loss: 5.9062 - val_y1_output_loss: 2.3200 - val_y2_output_loss: 3.5862 - val_y1_output_root_mean_squared_error: 1.5232 - val_y2_output_root_mean_squared_error: 1.8937
# Epoch 47/500
# 62/62 [==============================] - 0s 6ms/step - loss: 6.9051 - y1_output_loss: 2.4041 - y2_output_loss: 4.5010 - y1_output_root_mean_squared_error: 1.5505 - y2_output_root_mean_squared_error: 2.1215 - val_loss: 5.8977 - val_y1_output_loss: 2.3204 - val_y2_output_loss: 3.5773 - val_y1_output_root_mean_squared_error: 1.5233 - val_y2_output_root_mean_squared_error: 1.8914
# Epoch 48/500
# 62/62 [==============================] - 0s 6ms/step - loss: 6.7854 - y1_output_loss: 2.2887 - y2_output_loss: 4.4968 - y1_output_root_mean_squared_error: 1.5128 - y2_output_root_mean_squared_error: 2.1206 - val_loss: 5.7761 - val_y1_output_loss: 2.1663 - val_y2_output_loss: 3.6098 - val_y1_output_root_mean_squared_error: 1.4718 - val_y2_output_root_mean_squared_error: 1.8999
# Epoch 49/500
# 62/62 [==============================] - 0s 6ms/step - loss: 5.5355 - y1_output_loss: 1.9614 - y2_output_loss: 3.5741 - y1_output_root_mean_squared_error: 1.4005 - y2_output_root_mean_squared_error: 1.8905 - val_loss: 6.8414 - val_y1_output_loss: 2.1833 - val_y2_output_loss: 4.6581 - val_y1_output_root_mean_squared_error: 1.4776 - val_y2_output_root_mean_squared_error: 2.1583
# Epoch 50/500
# 62/62 [==============================] - 0s 5ms/step - loss: 5.9785 - y1_output_loss: 2.0430 - y2_output_loss: 3.9356 - y1_output_root_mean_squared_error: 1.4293 - y2_output_root_mean_squared_error: 1.9838 - val_loss: 7.2319 - val_y1_output_loss: 3.1682 - val_y2_output_loss: 4.0637 - val_y1_output_root_mean_squared_error: 1.7799 - val_y2_output_root_mean_squared_error: 2.0159
# Epoch 51/500
# 62/62 [==============================] - 0s 6ms/step - loss: 5.9006 - y1_output_loss: 1.8313 - y2_output_loss: 4.0693 - y1_output_root_mean_squared_error: 1.3533 - y2_output_root_mean_squared_error: 2.0173 - val_loss: 9.9599 - val_y1_output_loss: 3.5741 - val_y2_output_loss: 6.3858 - val_y1_output_root_mean_squared_error: 1.8905 - val_y2_output_root_mean_squared_error: 2.5270
# Epoch 52/500
# 62/62 [==============================] - 0s 6ms/step - loss: 7.0255 - y1_output_loss: 2.1131 - y2_output_loss: 4.9124 - y1_output_root_mean_squared_error: 1.4536 - y2_output_root_mean_squared_error: 2.2164 - val_loss: 6.4638 - val_y1_output_loss: 1.8708 - val_y2_output_loss: 4.5930 - val_y1_output_root_mean_squared_error: 1.3678 - val_y2_output_root_mean_squared_error: 2.1431
# Epoch 53/500
# 62/62 [==============================] - 0s 4ms/step - loss: 6.4146 - y1_output_loss: 1.9183 - y2_output_loss: 4.4963 - y1_output_root_mean_squared_error: 1.3850 - y2_output_root_mean_squared_error: 2.1204 - val_loss: 7.6473 - val_y1_output_loss: 2.9355 - val_y2_output_loss: 4.7119 - val_y1_output_root_mean_squared_error: 1.7133 - val_y2_output_root_mean_squared_error: 2.1707
# Epoch 54/500
# 62/62 [==============================] - 0s 3ms/step - loss: 5.0305 - y1_output_loss: 1.5357 - y2_output_loss: 3.4948 - y1_output_root_mean_squared_error: 1.2392 - y2_output_root_mean_squared_error: 1.8694 - val_loss: 10.0681 - val_y1_output_loss: 3.1289 - val_y2_output_loss: 6.9392 - val_y1_output_root_mean_squared_error: 1.7689 - val_y2_output_root_mean_squared_error: 2.6342
# Epoch 55/500
# 62/62 [==============================] - 0s 3ms/step - loss: 5.3179 - y1_output_loss: 1.6980 - y2_output_loss: 3.6199 - y1_output_root_mean_squared_error: 1.3031 - y2_output_root_mean_squared_error: 1.9026 - val_loss: 10.1012 - val_y1_output_loss: 4.1703 - val_y2_output_loss: 5.9309 - val_y1_output_root_mean_squared_error: 2.0421 - val_y2_output_root_mean_squared_error: 2.4353
# Epoch 56/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.7319 - y1_output_loss: 1.7581 - y2_output_loss: 3.9739 - y1_output_root_mean_squared_error: 1.3259 - y2_output_root_mean_squared_error: 1.9935 - val_loss: 7.4289 - val_y1_output_loss: 3.2244 - val_y2_output_loss: 4.2046 - val_y1_output_root_mean_squared_error: 1.7957 - val_y2_output_root_mean_squared_error: 2.0505
# Epoch 57/500
# 62/62 [==============================] - 0s 4ms/step - loss: 6.0382 - y1_output_loss: 1.7162 - y2_output_loss: 4.3220 - y1_output_root_mean_squared_error: 1.3100 - y2_output_root_mean_squared_error: 2.0789 - val_loss: 4.3584 - val_y1_output_loss: 1.4733 - val_y2_output_loss: 2.8851 - val_y1_output_root_mean_squared_error: 1.2138 - val_y2_output_root_mean_squared_error: 1.6986
# Epoch 58/500
# 62/62 [==============================] - 0s 3ms/step - loss: 4.4354 - y1_output_loss: 1.3707 - y2_output_loss: 3.0646 - y1_output_root_mean_squared_error: 1.1708 - y2_output_root_mean_squared_error: 1.7506 - val_loss: 26.4301 - val_y1_output_loss: 8.0632 - val_y2_output_loss: 18.3668 - val_y1_output_root_mean_squared_error: 2.8396 - val_y2_output_root_mean_squared_error: 4.2857
# Epoch 59/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.0066 - y1_output_loss: 1.2128 - y2_output_loss: 2.7938 - y1_output_root_mean_squared_error: 1.1013 - y2_output_root_mean_squared_error: 1.6715 - val_loss: 5.3073 - val_y1_output_loss: 2.0861 - val_y2_output_loss: 3.2212 - val_y1_output_root_mean_squared_error: 1.4443 - val_y2_output_root_mean_squared_error: 1.7948
# Epoch 60/500
# 62/62 [==============================] - 0s 3ms/step - loss: 4.8419 - y1_output_loss: 1.3676 - y2_output_loss: 3.4743 - y1_output_root_mean_squared_error: 1.1694 - y2_output_root_mean_squared_error: 1.8639 - val_loss: 12.7440 - val_y1_output_loss: 2.5632 - val_y2_output_loss: 10.1808 - val_y1_output_root_mean_squared_error: 1.6010 - val_y2_output_root_mean_squared_error: 3.1907
# Epoch 61/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.7813 - y1_output_loss: 1.5208 - y2_output_loss: 3.2605 - y1_output_root_mean_squared_error: 1.2332 - y2_output_root_mean_squared_error: 1.8057 - val_loss: 4.0312 - val_y1_output_loss: 1.3712 - val_y2_output_loss: 2.6600 - val_y1_output_root_mean_squared_error: 1.1710 - val_y2_output_root_mean_squared_error: 1.6309
# Epoch 62/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.8972 - y1_output_loss: 1.1028 - y2_output_loss: 2.7944 - y1_output_root_mean_squared_error: 1.0501 - y2_output_root_mean_squared_error: 1.6717 - val_loss: 5.6884 - val_y1_output_loss: 2.0543 - val_y2_output_loss: 3.6341 - val_y1_output_root_mean_squared_error: 1.4333 - val_y2_output_root_mean_squared_error: 1.9063
# Epoch 63/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.4667 - y1_output_loss: 1.2604 - y2_output_loss: 3.2063 - y1_output_root_mean_squared_error: 1.1227 - y2_output_root_mean_squared_error: 1.7906 - val_loss: 6.1506 - val_y1_output_loss: 1.1467 - val_y2_output_loss: 5.0039 - val_y1_output_root_mean_squared_error: 1.0708 - val_y2_output_root_mean_squared_error: 2.2369
# Epoch 64/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.5034 - y1_output_loss: 1.4066 - y2_output_loss: 4.0968 - y1_output_root_mean_squared_error: 1.1860 - y2_output_root_mean_squared_error: 2.0240 - val_loss: 4.1957 - val_y1_output_loss: 1.4117 - val_y2_output_loss: 2.7840 - val_y1_output_root_mean_squared_error: 1.1882 - val_y2_output_root_mean_squared_error: 1.6685
# Epoch 65/500
# 62/62 [==============================] - 0s 3ms/step - loss: 4.2681 - y1_output_loss: 1.2461 - y2_output_loss: 3.0219 - y1_output_root_mean_squared_error: 1.1163 - y2_output_root_mean_squared_error: 1.7384 - val_loss: 7.4393 - val_y1_output_loss: 2.1576 - val_y2_output_loss: 5.2817 - val_y1_output_root_mean_squared_error: 1.4689 - val_y2_output_root_mean_squared_error: 2.2982
# Epoch 66/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.8857 - y1_output_loss: 1.4267 - y2_output_loss: 3.4589 - y1_output_root_mean_squared_error: 1.1945 - y2_output_root_mean_squared_error: 1.8598 - val_loss: 8.9740 - val_y1_output_loss: 2.4266 - val_y2_output_loss: 6.5475 - val_y1_output_root_mean_squared_error: 1.5577 - val_y2_output_root_mean_squared_error: 2.5588
# Epoch 67/500
# 62/62 [==============================] - 0s 4ms/step - loss: 6.4801 - y1_output_loss: 1.7856 - y2_output_loss: 4.6945 - y1_output_root_mean_squared_error: 1.3363 - y2_output_root_mean_squared_error: 2.1667 - val_loss: 4.4657 - val_y1_output_loss: 1.2669 - val_y2_output_loss: 3.1987 - val_y1_output_root_mean_squared_error: 1.1256 - val_y2_output_root_mean_squared_error: 1.7885
# Epoch 68/500
# 62/62 [==============================] - 0s 6ms/step - loss: 3.8475 - y1_output_loss: 1.0738 - y2_output_loss: 2.7737 - y1_output_root_mean_squared_error: 1.0362 - y2_output_root_mean_squared_error: 1.6655 - val_loss: 6.7020 - val_y1_output_loss: 1.5755 - val_y2_output_loss: 5.1265 - val_y1_output_root_mean_squared_error: 1.2552 - val_y2_output_root_mean_squared_error: 2.2642
# Epoch 69/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.7618 - y1_output_loss: 1.0095 - y2_output_loss: 2.7523 - y1_output_root_mean_squared_error: 1.0047 - y2_output_root_mean_squared_error: 1.6590 - val_loss: 3.1631 - val_y1_output_loss: 0.9626 - val_y2_output_loss: 2.2005 - val_y1_output_root_mean_squared_error: 0.9811 - val_y2_output_root_mean_squared_error: 1.4834
# Epoch 70/500
# 62/62 [==============================] - 0s 5ms/step - loss: 4.3682 - y1_output_loss: 1.1626 - y2_output_loss: 3.2057 - y1_output_root_mean_squared_error: 1.0782 - y2_output_root_mean_squared_error: 1.7904 - val_loss: 3.9938 - val_y1_output_loss: 1.2120 - val_y2_output_loss: 2.7818 - val_y1_output_root_mean_squared_error: 1.1009 - val_y2_output_root_mean_squared_error: 1.6679
# Epoch 71/500
# 62/62 [==============================] - 0s 6ms/step - loss: 4.7678 - y1_output_loss: 1.3364 - y2_output_loss: 3.4314 - y1_output_root_mean_squared_error: 1.1560 - y2_output_root_mean_squared_error: 1.8524 - val_loss: 3.2654 - val_y1_output_loss: 1.0675 - val_y2_output_loss: 2.1979 - val_y1_output_root_mean_squared_error: 1.0332 - val_y2_output_root_mean_squared_error: 1.4825
# Epoch 72/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.0630 - y1_output_loss: 0.8005 - y2_output_loss: 2.2625 - y1_output_root_mean_squared_error: 0.8947 - y2_output_root_mean_squared_error: 1.5042 - val_loss: 3.5475 - val_y1_output_loss: 1.4292 - val_y2_output_loss: 2.1183 - val_y1_output_root_mean_squared_error: 1.1955 - val_y2_output_root_mean_squared_error: 1.4554
# Epoch 73/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.9844 - y1_output_loss: 0.8079 - y2_output_loss: 2.1765 - y1_output_root_mean_squared_error: 0.8989 - y2_output_root_mean_squared_error: 1.4753 - val_loss: 4.7480 - val_y1_output_loss: 1.1896 - val_y2_output_loss: 3.5584 - val_y1_output_root_mean_squared_error: 1.0907 - val_y2_output_root_mean_squared_error: 1.8864
# Epoch 74/500
# 62/62 [==============================] - 0s 5ms/step - loss: 3.2827 - y1_output_loss: 0.8782 - y2_output_loss: 2.4045 - y1_output_root_mean_squared_error: 0.9371 - y2_output_root_mean_squared_error: 1.5506 - val_loss: 3.4096 - val_y1_output_loss: 1.3447 - val_y2_output_loss: 2.0648 - val_y1_output_root_mean_squared_error: 1.1596 - val_y2_output_root_mean_squared_error: 1.4370
# Epoch 75/500
# 62/62 [==============================] - 0s 8ms/step - loss: 3.4051 - y1_output_loss: 0.8247 - y2_output_loss: 2.5804 - y1_output_root_mean_squared_error: 0.9081 - y2_output_root_mean_squared_error: 1.6064 - val_loss: 12.9066 - val_y1_output_loss: 3.3962 - val_y2_output_loss: 9.5105 - val_y1_output_root_mean_squared_error: 1.8429 - val_y2_output_root_mean_squared_error: 3.0839
# Epoch 76/500
# 62/62 [==============================] - 0s 6ms/step - loss: 3.3214 - y1_output_loss: 0.7948 - y2_output_loss: 2.5266 - y1_output_root_mean_squared_error: 0.8915 - y2_output_root_mean_squared_error: 1.5895 - val_loss: 5.0553 - val_y1_output_loss: 1.8863 - val_y2_output_loss: 3.1690 - val_y1_output_root_mean_squared_error: 1.3734 - val_y2_output_root_mean_squared_error: 1.7802
# Epoch 77/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.5823 - y1_output_loss: 1.2014 - y2_output_loss: 3.3809 - y1_output_root_mean_squared_error: 1.0961 - y2_output_root_mean_squared_error: 1.8387 - val_loss: 35.7024 - val_y1_output_loss: 10.2164 - val_y2_output_loss: 25.4860 - val_y1_output_root_mean_squared_error: 3.1963 - val_y2_output_root_mean_squared_error: 5.0484
# Epoch 78/500
# 62/62 [==============================] - 0s 6ms/step - loss: 4.2657 - y1_output_loss: 1.0697 - y2_output_loss: 3.1960 - y1_output_root_mean_squared_error: 1.0343 - y2_output_root_mean_squared_error: 1.7877 - val_loss: 6.7065 - val_y1_output_loss: 2.4036 - val_y2_output_loss: 4.3029 - val_y1_output_root_mean_squared_error: 1.5504 - val_y2_output_root_mean_squared_error: 2.0743
# Epoch 79/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.9157 - y1_output_loss: 0.8113 - y2_output_loss: 2.1043 - y1_output_root_mean_squared_error: 0.9007 - y2_output_root_mean_squared_error: 1.4506 - val_loss: 3.4839 - val_y1_output_loss: 0.7376 - val_y2_output_loss: 2.7462 - val_y1_output_root_mean_squared_error: 0.8589 - val_y2_output_root_mean_squared_error: 1.6572
# Epoch 80/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.8945 - y1_output_loss: 1.0120 - y2_output_loss: 2.8825 - y1_output_root_mean_squared_error: 1.0060 - y2_output_root_mean_squared_error: 1.6978 - val_loss: 2.9835 - val_y1_output_loss: 0.9179 - val_y2_output_loss: 2.0656 - val_y1_output_root_mean_squared_error: 0.9581 - val_y2_output_root_mean_squared_error: 1.4372
# Epoch 81/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.9125 - y1_output_loss: 0.7080 - y2_output_loss: 2.2045 - y1_output_root_mean_squared_error: 0.8414 - y2_output_root_mean_squared_error: 1.4848 - val_loss: 2.9736 - val_y1_output_loss: 0.9636 - val_y2_output_loss: 2.0100 - val_y1_output_root_mean_squared_error: 0.9816 - val_y2_output_root_mean_squared_error: 1.4177
# Epoch 82/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.7327 - y1_output_loss: 0.6883 - y2_output_loss: 2.0444 - y1_output_root_mean_squared_error: 0.8297 - y2_output_root_mean_squared_error: 1.4298 - val_loss: 3.1631 - val_y1_output_loss: 0.9525 - val_y2_output_loss: 2.2106 - val_y1_output_root_mean_squared_error: 0.9760 - val_y2_output_root_mean_squared_error: 1.4868
# Epoch 83/500
# 62/62 [==============================] - 0s 6ms/step - loss: 2.9011 - y1_output_loss: 0.7238 - y2_output_loss: 2.1773 - y1_output_root_mean_squared_error: 0.8508 - y2_output_root_mean_squared_error: 1.4756 - val_loss: 2.6986 - val_y1_output_loss: 0.7085 - val_y2_output_loss: 1.9901 - val_y1_output_root_mean_squared_error: 0.8417 - val_y2_output_root_mean_squared_error: 1.4107
# Epoch 84/500
# 62/62 [==============================] - 0s 6ms/step - loss: 3.5957 - y1_output_loss: 0.8889 - y2_output_loss: 2.7068 - y1_output_root_mean_squared_error: 0.9428 - y2_output_root_mean_squared_error: 1.6452 - val_loss: 2.5776 - val_y1_output_loss: 0.6907 - val_y2_output_loss: 1.8869 - val_y1_output_root_mean_squared_error: 0.8311 - val_y2_output_root_mean_squared_error: 1.3736
# Epoch 85/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.0981 - y1_output_loss: 1.0550 - y2_output_loss: 3.0431 - y1_output_root_mean_squared_error: 1.0271 - y2_output_root_mean_squared_error: 1.7444 - val_loss: 42.2241 - val_y1_output_loss: 13.4168 - val_y2_output_loss: 28.8073 - val_y1_output_root_mean_squared_error: 3.6629 - val_y2_output_root_mean_squared_error: 5.3672
# Epoch 86/500
# 62/62 [==============================] - 0s 3ms/step - loss: 4.7268 - y1_output_loss: 1.3382 - y2_output_loss: 3.3886 - y1_output_root_mean_squared_error: 1.1568 - y2_output_root_mean_squared_error: 1.8408 - val_loss: 4.0137 - val_y1_output_loss: 0.9987 - val_y2_output_loss: 3.0150 - val_y1_output_root_mean_squared_error: 0.9994 - val_y2_output_root_mean_squared_error: 1.7364
# Epoch 87/500
# 62/62 [==============================] - 0s 6ms/step - loss: 3.1359 - y1_output_loss: 0.7842 - y2_output_loss: 2.3517 - y1_output_root_mean_squared_error: 0.8856 - y2_output_root_mean_squared_error: 1.5335 - val_loss: 2.6977 - val_y1_output_loss: 0.6780 - val_y2_output_loss: 2.0197 - val_y1_output_root_mean_squared_error: 0.8234 - val_y2_output_root_mean_squared_error: 1.4212
# Epoch 88/500
# 62/62 [==============================] - 1s 10ms/step - loss: 3.1905 - y1_output_loss: 0.6999 - y2_output_loss: 2.4906 - y1_output_root_mean_squared_error: 0.8366 - y2_output_root_mean_squared_error: 1.5782 - val_loss: 2.7044 - val_y1_output_loss: 0.8611 - val_y2_output_loss: 1.8432 - val_y1_output_root_mean_squared_error: 0.9280 - val_y2_output_root_mean_squared_error: 1.3577
# Epoch 89/500
# 62/62 [==============================] - 1s 15ms/step - loss: 4.0803 - y1_output_loss: 1.0488 - y2_output_loss: 3.0315 - y1_output_root_mean_squared_error: 1.0241 - y2_output_root_mean_squared_error: 1.7411 - val_loss: 4.0188 - val_y1_output_loss: 1.2334 - val_y2_output_loss: 2.7855 - val_y1_output_root_mean_squared_error: 1.1106 - val_y2_output_root_mean_squared_error: 1.6690
# Epoch 90/500
# 62/62 [==============================] - 1s 10ms/step - loss: 2.5581 - y1_output_loss: 0.6796 - y2_output_loss: 1.8785 - y1_output_root_mean_squared_error: 0.8244 - y2_output_root_mean_squared_error: 1.3706 - val_loss: 7.3715 - val_y1_output_loss: 1.4684 - val_y2_output_loss: 5.9031 - val_y1_output_root_mean_squared_error: 1.2118 - val_y2_output_root_mean_squared_error: 2.4296
# Epoch 91/500
# 62/62 [==============================] - 0s 6ms/step - loss: 2.9497 - y1_output_loss: 0.6625 - y2_output_loss: 2.2873 - y1_output_root_mean_squared_error: 0.8139 - y2_output_root_mean_squared_error: 1.5124 - val_loss: 2.8139 - val_y1_output_loss: 0.6645 - val_y2_output_loss: 2.1494 - val_y1_output_root_mean_squared_error: 0.8152 - val_y2_output_root_mean_squared_error: 1.4661
# Epoch 92/500
# 62/62 [==============================] - 0s 8ms/step - loss: 3.1002 - y1_output_loss: 0.6910 - y2_output_loss: 2.4093 - y1_output_root_mean_squared_error: 0.8312 - y2_output_root_mean_squared_error: 1.5522 - val_loss: 3.1105 - val_y1_output_loss: 0.8318 - val_y2_output_loss: 2.2787 - val_y1_output_root_mean_squared_error: 0.9120 - val_y2_output_root_mean_squared_error: 1.5095
# Epoch 93/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.8413 - y1_output_loss: 0.7462 - y2_output_loss: 2.0951 - y1_output_root_mean_squared_error: 0.8638 - y2_output_root_mean_squared_error: 1.4475 - val_loss: 4.3357 - val_y1_output_loss: 1.3419 - val_y2_output_loss: 2.9939 - val_y1_output_root_mean_squared_error: 1.1584 - val_y2_output_root_mean_squared_error: 1.7303
# Epoch 94/500
# 62/62 [==============================] - 0s 6ms/step - loss: 3.0293 - y1_output_loss: 0.7457 - y2_output_loss: 2.2836 - y1_output_root_mean_squared_error: 0.8636 - y2_output_root_mean_squared_error: 1.5112 - val_loss: 6.9642 - val_y1_output_loss: 1.4085 - val_y2_output_loss: 5.5557 - val_y1_output_root_mean_squared_error: 1.1868 - val_y2_output_root_mean_squared_error: 2.3571
# Epoch 95/500
# 62/62 [==============================] - 0s 6ms/step - loss: 3.2120 - y1_output_loss: 0.7534 - y2_output_loss: 2.4587 - y1_output_root_mean_squared_error: 0.8680 - y2_output_root_mean_squared_error: 1.5680 - val_loss: 13.9978 - val_y1_output_loss: 4.8548 - val_y2_output_loss: 9.1431 - val_y1_output_root_mean_squared_error: 2.2034 - val_y2_output_root_mean_squared_error: 3.0238
# Epoch 96/500
# 62/62 [==============================] - 0s 5ms/step - loss: 3.5050 - y1_output_loss: 0.9305 - y2_output_loss: 2.5745 - y1_output_root_mean_squared_error: 0.9646 - y2_output_root_mean_squared_error: 1.6045 - val_loss: 3.4010 - val_y1_output_loss: 0.9043 - val_y2_output_loss: 2.4967 - val_y1_output_root_mean_squared_error: 0.9509 - val_y2_output_root_mean_squared_error: 1.5801
# Epoch 97/500
# 62/62 [==============================] - 1s 9ms/step - loss: 3.0619 - y1_output_loss: 0.6854 - y2_output_loss: 2.3766 - y1_output_root_mean_squared_error: 0.8279 - y2_output_root_mean_squared_error: 1.5416 - val_loss: 2.8587 - val_y1_output_loss: 0.9798 - val_y2_output_loss: 1.8789 - val_y1_output_root_mean_squared_error: 0.9899 - val_y2_output_root_mean_squared_error: 1.3707
# Epoch 98/500
# 62/62 [==============================] - 0s 6ms/step - loss: 3.6007 - y1_output_loss: 0.8528 - y2_output_loss: 2.7478 - y1_output_root_mean_squared_error: 0.9235 - y2_output_root_mean_squared_error: 1.6577 - val_loss: 7.2774 - val_y1_output_loss: 0.8355 - val_y2_output_loss: 6.4418 - val_y1_output_root_mean_squared_error: 0.9141 - val_y2_output_root_mean_squared_error: 2.5381
# Epoch 99/500
# 62/62 [==============================] - 0s 5ms/step - loss: 2.9780 - y1_output_loss: 0.6754 - y2_output_loss: 2.3026 - y1_output_root_mean_squared_error: 0.8218 - y2_output_root_mean_squared_error: 1.5174 - val_loss: 2.8657 - val_y1_output_loss: 0.5999 - val_y2_output_loss: 2.2659 - val_y1_output_root_mean_squared_error: 0.7745 - val_y2_output_root_mean_squared_error: 1.5053
# Epoch 100/500
# 62/62 [==============================] - 0s 6ms/step - loss: 2.6563 - y1_output_loss: 0.6834 - y2_output_loss: 1.9729 - y1_output_root_mean_squared_error: 0.8267 - y2_output_root_mean_squared_error: 1.4046 - val_loss: 2.5435 - val_y1_output_loss: 0.6650 - val_y2_output_loss: 1.8785 - val_y1_output_root_mean_squared_error: 0.8155 - val_y2_output_root_mean_squared_error: 1.3706
# Epoch 101/500
# 62/62 [==============================] - 0s 6ms/step - loss: 2.6656 - y1_output_loss: 0.6430 - y2_output_loss: 2.0226 - y1_output_root_mean_squared_error: 0.8019 - y2_output_root_mean_squared_error: 1.4222 - val_loss: 2.8961 - val_y1_output_loss: 0.9516 - val_y2_output_loss: 1.9445 - val_y1_output_root_mean_squared_error: 0.9755 - val_y2_output_root_mean_squared_error: 1.3945
# Epoch 102/500
# 62/62 [==============================] - 0s 7ms/step - loss: 2.3179 - y1_output_loss: 0.5856 - y2_output_loss: 1.7323 - y1_output_root_mean_squared_error: 0.7653 - y2_output_root_mean_squared_error: 1.3162 - val_loss: 2.7174 - val_y1_output_loss: 0.6437 - val_y2_output_loss: 2.0737 - val_y1_output_root_mean_squared_error: 0.8023 - val_y2_output_root_mean_squared_error: 1.4400
# Epoch 103/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.8796 - y1_output_loss: 1.3238 - y2_output_loss: 3.5558 - y1_output_root_mean_squared_error: 1.1506 - y2_output_root_mean_squared_error: 1.8857 - val_loss: 2.5396 - val_y1_output_loss: 0.6470 - val_y2_output_loss: 1.8926 - val_y1_output_root_mean_squared_error: 0.8043 - val_y2_output_root_mean_squared_error: 1.3757
# Epoch 104/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.5381 - y1_output_loss: 0.5778 - y2_output_loss: 1.9603 - y1_output_root_mean_squared_error: 0.7601 - y2_output_root_mean_squared_error: 1.4001 - val_loss: 3.1241 - val_y1_output_loss: 1.0415 - val_y2_output_loss: 2.0826 - val_y1_output_root_mean_squared_error: 1.0205 - val_y2_output_root_mean_squared_error: 1.4431
# Epoch 105/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.6788 - y1_output_loss: 0.6752 - y2_output_loss: 2.0036 - y1_output_root_mean_squared_error: 0.8217 - y2_output_root_mean_squared_error: 1.4155 - val_loss: 2.6605 - val_y1_output_loss: 0.5412 - val_y2_output_loss: 2.1193 - val_y1_output_root_mean_squared_error: 0.7357 - val_y2_output_root_mean_squared_error: 1.4558
# Epoch 106/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.4689 - y1_output_loss: 0.6128 - y2_output_loss: 1.8560 - y1_output_root_mean_squared_error: 0.7828 - y2_output_root_mean_squared_error: 1.3624 - val_loss: 2.2432 - val_y1_output_loss: 0.5634 - val_y2_output_loss: 1.6798 - val_y1_output_root_mean_squared_error: 0.7506 - val_y2_output_root_mean_squared_error: 1.2961
# Epoch 107/500
# 62/62 [==============================] - 0s 5ms/step - loss: 2.2065 - y1_output_loss: 0.5372 - y2_output_loss: 1.6693 - y1_output_root_mean_squared_error: 0.7329 - y2_output_root_mean_squared_error: 1.2920 - val_loss: 3.3243 - val_y1_output_loss: 0.6815 - val_y2_output_loss: 2.6428 - val_y1_output_root_mean_squared_error: 0.8256 - val_y2_output_root_mean_squared_error: 1.6257
# Epoch 108/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.1339 - y1_output_loss: 0.5019 - y2_output_loss: 1.6320 - y1_output_root_mean_squared_error: 0.7084 - y2_output_root_mean_squared_error: 1.2775 - val_loss: 2.0068 - val_y1_output_loss: 0.5308 - val_y2_output_loss: 1.4760 - val_y1_output_root_mean_squared_error: 0.7285 - val_y2_output_root_mean_squared_error: 1.2149
# Epoch 109/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.1547 - y1_output_loss: 0.5161 - y2_output_loss: 1.6386 - y1_output_root_mean_squared_error: 0.7184 - y2_output_root_mean_squared_error: 1.2801 - val_loss: 3.6007 - val_y1_output_loss: 0.9356 - val_y2_output_loss: 2.6651 - val_y1_output_root_mean_squared_error: 0.9673 - val_y2_output_root_mean_squared_error: 1.6325
# Epoch 110/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.1963 - y1_output_loss: 0.5609 - y2_output_loss: 1.6354 - y1_output_root_mean_squared_error: 0.7489 - y2_output_root_mean_squared_error: 1.2788 - val_loss: 4.7375 - val_y1_output_loss: 0.9205 - val_y2_output_loss: 3.8171 - val_y1_output_root_mean_squared_error: 0.9594 - val_y2_output_root_mean_squared_error: 1.9537
# Epoch 111/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.2787 - y1_output_loss: 0.7575 - y2_output_loss: 2.5212 - y1_output_root_mean_squared_error: 0.8703 - y2_output_root_mean_squared_error: 1.5878 - val_loss: 8.2354 - val_y1_output_loss: 1.3907 - val_y2_output_loss: 6.8447 - val_y1_output_root_mean_squared_error: 1.1793 - val_y2_output_root_mean_squared_error: 2.6162
# Epoch 112/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.4299 - y1_output_loss: 0.6489 - y2_output_loss: 1.7810 - y1_output_root_mean_squared_error: 0.8055 - y2_output_root_mean_squared_error: 1.3345 - val_loss: 2.3006 - val_y1_output_loss: 0.6849 - val_y2_output_loss: 1.6157 - val_y1_output_root_mean_squared_error: 0.8276 - val_y2_output_root_mean_squared_error: 1.2711
# Epoch 113/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.3354 - y1_output_loss: 0.5375 - y2_output_loss: 1.7978 - y1_output_root_mean_squared_error: 0.7332 - y2_output_root_mean_squared_error: 1.3408 - val_loss: 2.4301 - val_y1_output_loss: 0.6454 - val_y2_output_loss: 1.7848 - val_y1_output_root_mean_squared_error: 0.8034 - val_y2_output_root_mean_squared_error: 1.3359
# Epoch 114/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.4427 - y1_output_loss: 0.8162 - y2_output_loss: 2.6265 - y1_output_root_mean_squared_error: 0.9034 - y2_output_root_mean_squared_error: 1.6207 - val_loss: 25.9006 - val_y1_output_loss: 7.7418 - val_y2_output_loss: 18.1588 - val_y1_output_root_mean_squared_error: 2.7824 - val_y2_output_root_mean_squared_error: 4.2613
# Epoch 115/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.5823 - y1_output_loss: 0.7057 - y2_output_loss: 1.8766 - y1_output_root_mean_squared_error: 0.8401 - y2_output_root_mean_squared_error: 1.3699 - val_loss: 2.3991 - val_y1_output_loss: 0.4728 - val_y2_output_loss: 1.9263 - val_y1_output_root_mean_squared_error: 0.6876 - val_y2_output_root_mean_squared_error: 1.3879
# Epoch 116/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.2912 - y1_output_loss: 0.5445 - y2_output_loss: 1.7467 - y1_output_root_mean_squared_error: 0.7379 - y2_output_root_mean_squared_error: 1.3216 - val_loss: 2.7307 - val_y1_output_loss: 0.9642 - val_y2_output_loss: 1.7665 - val_y1_output_root_mean_squared_error: 0.9819 - val_y2_output_root_mean_squared_error: 1.3291
# Epoch 117/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.5233 - y1_output_loss: 0.5986 - y2_output_loss: 1.9247 - y1_output_root_mean_squared_error: 0.7737 - y2_output_root_mean_squared_error: 1.3873 - val_loss: 4.8866 - val_y1_output_loss: 0.9692 - val_y2_output_loss: 3.9173 - val_y1_output_root_mean_squared_error: 0.9845 - val_y2_output_root_mean_squared_error: 1.9792
# Epoch 118/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.0860 - y1_output_loss: 0.4626 - y2_output_loss: 1.6234 - y1_output_root_mean_squared_error: 0.6802 - y2_output_root_mean_squared_error: 1.2741 - val_loss: 10.4981 - val_y1_output_loss: 1.4014 - val_y2_output_loss: 9.0968 - val_y1_output_root_mean_squared_error: 1.1838 - val_y2_output_root_mean_squared_error: 3.0161
# Epoch 119/500
# 62/62 [==============================] - 0s 4ms/step - loss: 1.9777 - y1_output_loss: 0.5073 - y2_output_loss: 1.4704 - y1_output_root_mean_squared_error: 0.7122 - y2_output_root_mean_squared_error: 1.2126 - val_loss: 2.7685 - val_y1_output_loss: 0.8094 - val_y2_output_loss: 1.9591 - val_y1_output_root_mean_squared_error: 0.8997 - val_y2_output_root_mean_squared_error: 1.3997
# Epoch 120/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.5748 - y1_output_loss: 0.5641 - y2_output_loss: 2.0107 - y1_output_root_mean_squared_error: 0.7511 - y2_output_root_mean_squared_error: 1.4180 - val_loss: 2.0245 - val_y1_output_loss: 0.4797 - val_y2_output_loss: 1.5448 - val_y1_output_root_mean_squared_error: 0.6926 - val_y2_output_root_mean_squared_error: 1.2429
# Epoch 121/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.6286 - y1_output_loss: 0.6530 - y2_output_loss: 1.9756 - y1_output_root_mean_squared_error: 0.8081 - y2_output_root_mean_squared_error: 1.4055 - val_loss: 2.4707 - val_y1_output_loss: 0.5529 - val_y2_output_loss: 1.9178 - val_y1_output_root_mean_squared_error: 0.7436 - val_y2_output_root_mean_squared_error: 1.3848
# Epoch 122/500
# ...
# Epoch 461/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4533 - y1_output_loss: 0.1288 - y2_output_loss: 0.3245 - y1_output_root_mean_squared_error: 0.3589 - y2_output_root_mean_squared_error: 0.5696 - val_loss: 1.0978 - val_y1_output_loss: 0.2503 - val_y2_output_loss: 0.8476 - val_y1_output_root_mean_squared_error: 0.5003 - val_y2_output_root_mean_squared_error: 0.9206
# Epoch 462/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5100 - y1_output_loss: 0.1453 - y2_output_loss: 0.3647 - y1_output_root_mean_squared_error: 0.3812 - y2_output_root_mean_squared_error: 0.6039 - val_loss: 0.7836 - val_y1_output_loss: 0.1961 - val_y2_output_loss: 0.5875 - val_y1_output_root_mean_squared_error: 0.4428 - val_y2_output_root_mean_squared_error: 0.7665
# Epoch 463/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3717 - y1_output_loss: 0.1156 - y2_output_loss: 0.2561 - y1_output_root_mean_squared_error: 0.3400 - y2_output_root_mean_squared_error: 0.5061 - val_loss: 1.0424 - val_y1_output_loss: 0.4072 - val_y2_output_loss: 0.6352 - val_y1_output_root_mean_squared_error: 0.6381 - val_y2_output_root_mean_squared_error: 0.7970
# Epoch 464/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4388 - y1_output_loss: 0.1309 - y2_output_loss: 0.3079 - y1_output_root_mean_squared_error: 0.3618 - y2_output_root_mean_squared_error: 0.5549 - val_loss: 0.8074 - val_y1_output_loss: 0.2065 - val_y2_output_loss: 0.6009 - val_y1_output_root_mean_squared_error: 0.4544 - val_y2_output_root_mean_squared_error: 0.7752
# Epoch 465/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3637 - y1_output_loss: 0.1159 - y2_output_loss: 0.2478 - y1_output_root_mean_squared_error: 0.3405 - y2_output_root_mean_squared_error: 0.4978 - val_loss: 0.9716 - val_y1_output_loss: 0.2317 - val_y2_output_loss: 0.7399 - val_y1_output_root_mean_squared_error: 0.4813 - val_y2_output_root_mean_squared_error: 0.8602
# Epoch 466/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3570 - y1_output_loss: 0.1081 - y2_output_loss: 0.2489 - y1_output_root_mean_squared_error: 0.3288 - y2_output_root_mean_squared_error: 0.4989 - val_loss: 0.6634 - val_y1_output_loss: 0.1760 - val_y2_output_loss: 0.4874 - val_y1_output_root_mean_squared_error: 0.4196 - val_y2_output_root_mean_squared_error: 0.6981
# Epoch 467/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3790 - y1_output_loss: 0.1202 - y2_output_loss: 0.2588 - y1_output_root_mean_squared_error: 0.3467 - y2_output_root_mean_squared_error: 0.5087 - val_loss: 1.0400 - val_y1_output_loss: 0.3561 - val_y2_output_loss: 0.6839 - val_y1_output_root_mean_squared_error: 0.5967 - val_y2_output_root_mean_squared_error: 0.8270
# Epoch 468/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5198 - y1_output_loss: 0.1457 - y2_output_loss: 0.3740 - y1_output_root_mean_squared_error: 0.3817 - y2_output_root_mean_squared_error: 0.6116 - val_loss: 1.2669 - val_y1_output_loss: 0.2822 - val_y2_output_loss: 0.9847 - val_y1_output_root_mean_squared_error: 0.5312 - val_y2_output_root_mean_squared_error: 0.9923
# Epoch 469/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3953 - y1_output_loss: 0.1062 - y2_output_loss: 0.2891 - y1_output_root_mean_squared_error: 0.3258 - y2_output_root_mean_squared_error: 0.5377 - val_loss: 0.7738 - val_y1_output_loss: 0.1765 - val_y2_output_loss: 0.5974 - val_y1_output_root_mean_squared_error: 0.4201 - val_y2_output_root_mean_squared_error: 0.7729
# Epoch 470/500
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4333 - y1_output_loss: 0.1250 - y2_output_loss: 0.3083 - y1_output_root_mean_squared_error: 0.3536 - y2_output_root_mean_squared_error: 0.5552 - val_loss: 1.0680 - val_y1_output_loss: 0.2871 - val_y2_output_loss: 0.7810 - val_y1_output_root_mean_squared_error: 0.5358 - val_y2_output_root_mean_squared_error: 0.8837
# Epoch 471/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5479 - y1_output_loss: 0.1319 - y2_output_loss: 0.4161 - y1_output_root_mean_squared_error: 0.3631 - y2_output_root_mean_squared_error: 0.6450 - val_loss: 0.7738 - val_y1_output_loss: 0.2230 - val_y2_output_loss: 0.5507 - val_y1_output_root_mean_squared_error: 0.4723 - val_y2_output_root_mean_squared_error: 0.7421
# Epoch 472/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4650 - y1_output_loss: 0.1329 - y2_output_loss: 0.3322 - y1_output_root_mean_squared_error: 0.3645 - y2_output_root_mean_squared_error: 0.5763 - val_loss: 0.7127 - val_y1_output_loss: 0.2054 - val_y2_output_loss: 0.5073 - val_y1_output_root_mean_squared_error: 0.4532 - val_y2_output_root_mean_squared_error: 0.7123
# Epoch 473/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4195 - y1_output_loss: 0.1291 - y2_output_loss: 0.2904 - y1_output_root_mean_squared_error: 0.3593 - y2_output_root_mean_squared_error: 0.5389 - val_loss: 0.7442 - val_y1_output_loss: 0.2305 - val_y2_output_loss: 0.5137 - val_y1_output_root_mean_squared_error: 0.4801 - val_y2_output_root_mean_squared_error: 0.7167
# Epoch 474/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3439 - y1_output_loss: 0.1105 - y2_output_loss: 0.2334 - y1_output_root_mean_squared_error: 0.3324 - y2_output_root_mean_squared_error: 0.4831 - val_loss: 1.0179 - val_y1_output_loss: 0.2470 - val_y2_output_loss: 0.7709 - val_y1_output_root_mean_squared_error: 0.4970 - val_y2_output_root_mean_squared_error: 0.8780
# Epoch 475/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5128 - y1_output_loss: 0.1249 - y2_output_loss: 0.3878 - y1_output_root_mean_squared_error: 0.3535 - y2_output_root_mean_squared_error: 0.6228 - val_loss: 1.9241 - val_y1_output_loss: 0.4010 - val_y2_output_loss: 1.5231 - val_y1_output_root_mean_squared_error: 0.6333 - val_y2_output_root_mean_squared_error: 1.2341
# Epoch 476/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4817 - y1_output_loss: 0.1206 - y2_output_loss: 0.3610 - y1_output_root_mean_squared_error: 0.3473 - y2_output_root_mean_squared_error: 0.6009 - val_loss: 0.8915 - val_y1_output_loss: 0.2370 - val_y2_output_loss: 0.6545 - val_y1_output_root_mean_squared_error: 0.4868 - val_y2_output_root_mean_squared_error: 0.8090
# Epoch 477/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4082 - y1_output_loss: 0.1267 - y2_output_loss: 0.2815 - y1_output_root_mean_squared_error: 0.3559 - y2_output_root_mean_squared_error: 0.5306 - val_loss: 0.7230 - val_y1_output_loss: 0.1900 - val_y2_output_loss: 0.5329 - val_y1_output_root_mean_squared_error: 0.4359 - val_y2_output_root_mean_squared_error: 0.7300
# Epoch 478/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3996 - y1_output_loss: 0.1266 - y2_output_loss: 0.2729 - y1_output_root_mean_squared_error: 0.3559 - y2_output_root_mean_squared_error: 0.5224 - val_loss: 0.7447 - val_y1_output_loss: 0.2216 - val_y2_output_loss: 0.5231 - val_y1_output_root_mean_squared_error: 0.4707 - val_y2_output_root_mean_squared_error: 0.7233
# Epoch 479/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3412 - y1_output_loss: 0.1141 - y2_output_loss: 0.2271 - y1_output_root_mean_squared_error: 0.3378 - y2_output_root_mean_squared_error: 0.4766 - val_loss: 0.6720 - val_y1_output_loss: 0.1940 - val_y2_output_loss: 0.4780 - val_y1_output_root_mean_squared_error: 0.4405 - val_y2_output_root_mean_squared_error: 0.6914
# Epoch 480/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3647 - y1_output_loss: 0.1113 - y2_output_loss: 0.2534 - y1_output_root_mean_squared_error: 0.3336 - y2_output_root_mean_squared_error: 0.5034 - val_loss: 0.8534 - val_y1_output_loss: 0.1897 - val_y2_output_loss: 0.6637 - val_y1_output_root_mean_squared_error: 0.4355 - val_y2_output_root_mean_squared_error: 0.8147
# Epoch 481/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3945 - y1_output_loss: 0.1218 - y2_output_loss: 0.2727 - y1_output_root_mean_squared_error: 0.3490 - y2_output_root_mean_squared_error: 0.5222 - val_loss: 0.7505 - val_y1_output_loss: 0.2324 - val_y2_output_loss: 0.5181 - val_y1_output_root_mean_squared_error: 0.4821 - val_y2_output_root_mean_squared_error: 0.7198
# Epoch 482/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3847 - y1_output_loss: 0.1198 - y2_output_loss: 0.2649 - y1_output_root_mean_squared_error: 0.3462 - y2_output_root_mean_squared_error: 0.5146 - val_loss: 1.2535 - val_y1_output_loss: 0.2595 - val_y2_output_loss: 0.9940 - val_y1_output_root_mean_squared_error: 0.5094 - val_y2_output_root_mean_squared_error: 0.9970
# Epoch 483/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5281 - y1_output_loss: 0.1428 - y2_output_loss: 0.3853 - y1_output_root_mean_squared_error: 0.3778 - y2_output_root_mean_squared_error: 0.6207 - val_loss: 1.0889 - val_y1_output_loss: 0.2390 - val_y2_output_loss: 0.8499 - val_y1_output_root_mean_squared_error: 0.4889 - val_y2_output_root_mean_squared_error: 0.9219
# Epoch 484/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3711 - y1_output_loss: 0.1072 - y2_output_loss: 0.2639 - y1_output_root_mean_squared_error: 0.3275 - y2_output_root_mean_squared_error: 0.5137 - val_loss: 0.9773 - val_y1_output_loss: 0.1979 - val_y2_output_loss: 0.7794 - val_y1_output_root_mean_squared_error: 0.4449 - val_y2_output_root_mean_squared_error: 0.8828
# Epoch 485/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4685 - y1_output_loss: 0.1316 - y2_output_loss: 0.3369 - y1_output_root_mean_squared_error: 0.3628 - y2_output_root_mean_squared_error: 0.5804 - val_loss: 0.6952 - val_y1_output_loss: 0.2113 - val_y2_output_loss: 0.4840 - val_y1_output_root_mean_squared_error: 0.4596 - val_y2_output_root_mean_squared_error: 0.6957
# Epoch 486/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3651 - y1_output_loss: 0.1204 - y2_output_loss: 0.2447 - y1_output_root_mean_squared_error: 0.3470 - y2_output_root_mean_squared_error: 0.4947 - val_loss: 0.7130 - val_y1_output_loss: 0.1892 - val_y2_output_loss: 0.5237 - val_y1_output_root_mean_squared_error: 0.4350 - val_y2_output_root_mean_squared_error: 0.7237
# Epoch 487/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5450 - y1_output_loss: 0.1468 - y2_output_loss: 0.3982 - y1_output_root_mean_squared_error: 0.3832 - y2_output_root_mean_squared_error: 0.6310 - val_loss: 1.6276 - val_y1_output_loss: 0.4961 - val_y2_output_loss: 1.1315 - val_y1_output_root_mean_squared_error: 0.7043 - val_y2_output_root_mean_squared_error: 1.0637
# Epoch 488/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4751 - y1_output_loss: 0.1367 - y2_output_loss: 0.3384 - y1_output_root_mean_squared_error: 0.3698 - y2_output_root_mean_squared_error: 0.5817 - val_loss: 1.2950 - val_y1_output_loss: 0.1966 - val_y2_output_loss: 1.0984 - val_y1_output_root_mean_squared_error: 0.4434 - val_y2_output_root_mean_squared_error: 1.0481
# Epoch 489/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3690 - y1_output_loss: 0.1114 - y2_output_loss: 0.2576 - y1_output_root_mean_squared_error: 0.3338 - y2_output_root_mean_squared_error: 0.5076 - val_loss: 1.1198 - val_y1_output_loss: 0.2936 - val_y2_output_loss: 0.8262 - val_y1_output_root_mean_squared_error: 0.5418 - val_y2_output_root_mean_squared_error: 0.9090
# Epoch 490/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4470 - y1_output_loss: 0.1297 - y2_output_loss: 0.3172 - y1_output_root_mean_squared_error: 0.3602 - y2_output_root_mean_squared_error: 0.5632 - val_loss: 1.2748 - val_y1_output_loss: 0.2687 - val_y2_output_loss: 1.0061 - val_y1_output_root_mean_squared_error: 0.5184 - val_y2_output_root_mean_squared_error: 1.0030
# Epoch 491/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4041 - y1_output_loss: 0.1172 - y2_output_loss: 0.2869 - y1_output_root_mean_squared_error: 0.3423 - y2_output_root_mean_squared_error: 0.5356 - val_loss: 0.8737 - val_y1_output_loss: 0.1895 - val_y2_output_loss: 0.6843 - val_y1_output_root_mean_squared_error: 0.4353 - val_y2_output_root_mean_squared_error: 0.8272
# Epoch 492/500
# 62/62 [==============================] - 0s 6ms/step - loss: 0.3620 - y1_output_loss: 0.1077 - y2_output_loss: 0.2543 - y1_output_root_mean_squared_error: 0.3282 - y2_output_root_mean_squared_error: 0.5042 - val_loss: 2.7047 - val_y1_output_loss: 0.4642 - val_y2_output_loss: 2.2405 - val_y1_output_root_mean_squared_error: 0.6813 - val_y2_output_root_mean_squared_error: 1.4968
# Epoch 493/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5040 - y1_output_loss: 0.1480 - y2_output_loss: 0.3560 - y1_output_root_mean_squared_error: 0.3847 - y2_output_root_mean_squared_error: 0.5967 - val_loss: 0.7630 - val_y1_output_loss: 0.1883 - val_y2_output_loss: 0.5747 - val_y1_output_root_mean_squared_error: 0.4340 - val_y2_output_root_mean_squared_error: 0.7581
# Epoch 494/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5012 - y1_output_loss: 0.1420 - y2_output_loss: 0.3592 - y1_output_root_mean_squared_error: 0.3768 - y2_output_root_mean_squared_error: 0.5994 - val_loss: 0.8621 - val_y1_output_loss: 0.2256 - val_y2_output_loss: 0.6366 - val_y1_output_root_mean_squared_error: 0.4749 - val_y2_output_root_mean_squared_error: 0.7979
# Epoch 495/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5234 - y1_output_loss: 0.1293 - y2_output_loss: 0.3941 - y1_output_root_mean_squared_error: 0.3596 - y2_output_root_mean_squared_error: 0.6278 - val_loss: 0.7201 - val_y1_output_loss: 0.1811 - val_y2_output_loss: 0.5390 - val_y1_output_root_mean_squared_error: 0.4255 - val_y2_output_root_mean_squared_error: 0.7342
# Epoch 496/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3573 - y1_output_loss: 0.1139 - y2_output_loss: 0.2434 - y1_output_root_mean_squared_error: 0.3376 - y2_output_root_mean_squared_error: 0.4933 - val_loss: 0.7271 - val_y1_output_loss: 0.1938 - val_y2_output_loss: 0.5333 - val_y1_output_root_mean_squared_error: 0.4402 - val_y2_output_root_mean_squared_error: 0.7302
# Epoch 497/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3541 - y1_output_loss: 0.1131 - y2_output_loss: 0.2410 - y1_output_root_mean_squared_error: 0.3363 - y2_output_root_mean_squared_error: 0.4909 - val_loss: 0.9216 - val_y1_output_loss: 0.2504 - val_y2_output_loss: 0.6712 - val_y1_output_root_mean_squared_error: 0.5004 - val_y2_output_root_mean_squared_error: 0.8193
# Epoch 498/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3657 - y1_output_loss: 0.1116 - y2_output_loss: 0.2541 - y1_output_root_mean_squared_error: 0.3340 - y2_output_root_mean_squared_error: 0.5041 - val_loss: 0.7198 - val_y1_output_loss: 0.1968 - val_y2_output_loss: 0.5230 - val_y1_output_root_mean_squared_error: 0.4436 - val_y2_output_root_mean_squared_error: 0.7232
# Epoch 499/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3887 - y1_output_loss: 0.1244 - y2_output_loss: 0.2642 - y1_output_root_mean_squared_error: 0.3527 - y2_output_root_mean_squared_error: 0.5140 - val_loss: 0.8422 - val_y1_output_loss: 0.2552 - val_y2_output_loss: 0.5869 - val_y1_output_root_mean_squared_error: 0.5052 - val_y2_output_root_mean_squared_error: 0.7661
# Epoch 500/500
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4162 - y1_output_loss: 0.1146 - y2_output_loss: 0.3016 - y1_output_root_mean_squared_error: 0.3385 - y2_output_root_mean_squared_error: 0.5492 - val_loss: 1.8681 - val_y1_output_loss: 0.4862 - val_y2_output_loss: 1.3819 - val_y1_output_root_mean_squared_error: 0.6973 - val_y2_output_root_mean_squared_error: 1.1756

# %% [markdown]
# ## Evaluate model and plot Metrics

# %%
model.evaluate(norm_test_X, test_Y)
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 1.8681 - y1_output_loss: 0.4862 - y2_output_loss: 1.3819 - y1_output_root_mean_squared_error: 0.6973 - y2_output_root_mean_squared_error: 1.1756
# [1.8681414127349854,
#  0.4862003028392792,
#  1.381941318511963,
#  0.6972806453704834,
#  1.1755599975585938]

# %%
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
# Out:
# 5/5 [==============================] - 0s 3ms/step
